# %%
#В программе генерируется случайное целое число от 0 до 100.
#Пользователь должен его отгадать не более чем за 10 попыток.
#После каждой неудачной попытки должно сообщаться, больше или меньше введенное пользователем число,
#чем то, что загадано. Если за 10 попыток число не отгадано, вывести ответ.

import random
x=random.randint(0,100)
i=0
def conj (x,i):
    try:
        y=int(input('Попытайтесь угадать загаданное число от 0 до 100. Введите целое число. Введите \'-1\' для завершения. '))
    except ValueError:
        print('Внимание! Вводить можно только целые числа!\nПопробуйте еще раз.')
        y=-2
        i+=1
    if y==x:
        print('Вам удалось угадать загаданное число!')
    elif y<x:
        print('Вы не угадали. Ваше число меньше загаданного.')
    else:
        print('Вы не угадали. Ваше число больше загаданного.')
    if i<10 and y!=x and y!=-1:
        i+=1        
        conj(x,i)
    elif i==10:
        print('Вы так и не угадали загаданное число:(')
conj(x,i)
# Out:
# Попытайтесь угадать загаданное число от 0 до 100. Введите целое число. Введите '-1' для завершения. 1
# Вы не угадали. Ваше число меньше загаданного.
# Попытайтесь угадать загаданное число от 0 до 100. Введите целое число. Введите '-1' для завершения. 2
# Вы не угадали. Ваше число меньше загаданного.
# Попытайтесь угадать загаданное число от 0 до 100. Введите целое число. Введите '-1' для завершения. 3
# Вы не угадали. Ваше число меньше загаданного.
# Попытайтесь угадать загаданное число от 0 до 100. Введите целое число. Введите '-1' для завершения. 4
# Вы не угадали. Ваше число меньше загаданного.
# Попытайтесь угадать загаданное число от 0 до 100. Введите целое число. Введите '-1' для завершения. 5
# Вы не угадали. Ваше число меньше загаданного.
# Попытайтесь угадать загаданное число от 0 до 100. Введите целое число. Введите '-1' для завершения.
# Внимание! Вводить можно только целые числа!
# Попробуйте еще раз.
# Вы не угадали. Ваше число меньше загаданного.
# Попытайтесь угадать загаданное число от 0 до 100. Введите целое число. Введите '-1' для завершения. 6
# Вы не угадали. Ваше число меньше загаданного.
# Попытайтесь угадать загаданное число от 0 до 100. Введите целое число. Введите '-1' для завершения. 78
# Вы не угадали. Ваше число меньше загаданного.
# Попытайтесь угадать загаданное число от 0 до 100. Введите целое число. Введите '-1' для завершения.
# Внимание! Вводить можно только целые числа!
# Попробуйте еще раз.
# Вы не угадали. Ваше число меньше загаданного.
# Вы так и не угадали загаданное число:(
# 10

# %%
import random, timeit
x=random.randint(0,100)
listx=[i for i in range(0,101)]
def conj (x,listx):
    y=0
    if x!=y:
        try:
            y=int(input('Попытайтесь угадать загаданное число от 0 до 100. Введите целое число. Введите \'-1\' для завершения. '))
        except ValueError:
            print('Внимание! Вводить можно только целые числа!\nПопробуйте еще раз.')
            y=-2
        if x!=y:
            if x in listx[:y]:
                listx=listx[:y]
                print('Загаданное число меньше!')
            elif x in listx[y:]:
                y=y-len(listx[:y])
                listx=listx[y:]
                print('Загаданное число больше!')
            conj(x,listx)
        else:
            print('Вам удалось угадать загаданное число!')
            print(f'y={y}')
    return
conj(x,listx)
# Out:
# Попытайтесь угадать загаданное число от 0 до 100. Введите целое число. Введите '-1' для завершения. 50
# Загаданное число меньше!
# Попытайтесь угадать загаданное число от 0 до 100. Введите целое число. Введите '-1' для завершения. 25
# Загаданное число меньше!
# Попытайтесь угадать загаданное число от 0 до 100. Введите целое число. Введите '-1' для завершения. 12
# Загаданное число больше!
# Попытайтесь угадать загаданное число от 0 до 100. Введите целое число. Введите '-1' для завершения. 19
# Загаданное число больше!
# Попытайтесь угадать загаданное число от 0 до 100. Введите целое число. Введите '-1' для завершения. 22
# Загаданное число больше!
# Попытайтесь угадать загаданное число от 0 до 100. Введите целое число. Введите '-1' для завершения. 23
# Вам удалось угадать загаданное число!
# y=23
