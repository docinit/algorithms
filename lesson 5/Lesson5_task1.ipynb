# %%
#1. Пользователь вводит данные о количестве предприятий,
#их наименования и прибыль за четыре квартала для каждого предприятия.
#Программа должна определить среднюю прибыль (за год для всех предприятий)
#и отдельно вывести наименования предприятий, чья прибыль выше среднего и ниже среднего.


from collections import defaultdict,OrderedDict

a=int(input('Задайте количество компаний: '))

comp_dict=OrderedDict()
com_income=0
for i in range(a):
    k=str(input('Введите название компаний (по-одной): '))
    comp_dict[k]=1

for k in comp_dict:
    comp_dict[k]=(float(input(f'Введите прибыль за первый квартал для "{k}": ')),
                     float(input(f'Введите прибыль за второй квартал для "{k}": ')),
                         float(input(f'Введите прибыль за третий квартал для "{k}": ')),
                             float(input(f'Введите прибыль за четвертый квартал для "{k}": ')))


summa=0
for i in comp_dict:
    summa+=sum(comp_dict[i])
print('Средний доход за год: ', summa/a)
less=[]
more=[]
for i in comp_dict:
    s = sum(comp_dict[i])
    if s<summa/a:
        less.append(i)
    if s>summa/a:
        more.append(i)
print(f'Компания/ии {", ".join(more)} заработала/и больше среднего')
print(f'Компания/ии {", ".join(less)} заработала/и меньше среднего')
# Out:
# Задайте количество компаний: 4
# Введите название компаний (по-одной): Первая
# Введите название компаний (по-одной): Вторая
# Введите название компаний (по-одной): Третья
# Введите название компаний (по-одной): Четвертая
# Введите прибыль за первый квартал для "Первая": 10
# Введите прибыль за второй квартал для "Первая": 20
# Введите прибыль за третий квартал для "Первая": 30
# Введите прибыль за четвертый квартал для "Первая": 40
# Введите прибыль за первый квартал для "Вторая": 50
# Введите прибыль за второй квартал для "Вторая": 60
# Введите прибыль за третий квартал для "Вторая": 70
# Введите прибыль за четвертый квартал для "Вторая": 50
# Введите прибыль за первый квартал для "Третья": 40
# Введите прибыль за второй квартал для "Третья": 60
# Введите прибыль за третий квартал для "Третья": 80
# Введите прибыль за четвертый квартал для "Третья": 120
# Введите прибыль за первый квартал для "Четвертая": 20
# Введите прибыль за второй квартал для "Четвертая": 50
# Введите прибыль за третий квартал для "Четвертая": 60
# Введите прибыль за четвертый квартал для "Четвертая": 100
# Средний доход за год:  215.0
# Компания/ии Вторая, Третья, Четвертая заработала/и больше среднего
# Компания/ии Первая заработала/и меньше среднего
